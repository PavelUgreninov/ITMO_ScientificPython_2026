# %%
from datetime import datetime
# !pip install openmeteo_requests

import openmeteo_requests

class IncreaseSpeed():
  '''
  Iterator for increasing the speed with the default step of 10 km/h
  You can implement this one after Iterators FP topic

  Constructor params:
    current_speed: a value to start with, km/h
    max_speed: a maximum possible value, km/h
    step: a parameter to vary the value to increase by

  Make sure your iterator is not exceeding the maximum allowed value
  '''

  def __init__(self, current_speed: int, max_speed: int, step = 10):

    self.current_speed = current_speed
    self.max_speed = max_speed
    self.step = step

  def __iter__(self):
    return self

  def __next__(self, step = 10):

    limit = self.max_speed
    speed = self.current_speed

    if self.current_speed >= limit:
      raise StopIteration("You cannot move faster. Slow down!")
    else:
      self.current_speed = speed + step
      return speed


class DecreaseSpeed():
  '''
  Iterator for decreasing the speed with the default step of 10 km/h
  You can implement this one after Iterators FP topic

  Constructor params:
    current_speed: a value to start with, km/h

  Make sure your iterator is not going below zero
  '''

  def __init__(self, current_speed: int, min_speed: int, step = 10):

    self.current_speed = current_speed
    self.min_speed = min_speed
    self.step = step

  def __iter__(self):
    return self

  def __next__(self, step = 10):

    limit = self.min_speed
    speed = self.current_speed

    if self.current_speed <= limit:
      raise StopIteration("You cannot move slower. Speed up!")
    else:
      self.current_speed = speed - step
      return speed

class Car():

  TOTAL_CARS = 0
  '''
  Car class.
  Has a class variable for counting total amount of cars on the road (increased by 1 upon instance initialization).

  Constructor params:
    max_speed: a maximum possible speed, km/h
    current_speed: current speed, km/h (0 by default)
    state: reflects if the Car is in the parking or on the road

  Methods:
    accelerate: increases the speed using IncreaseSpeed() iterator either once or gradually to the upper_border
    brake: decreases the speed using DecreaseSpeed() iterator either once or gradually to the lower_border
    parking: if the Car is not already in the parking, removes the Car from the road
    total_cars: show the total amount of cars on the road
    show_weather: shows the current weather conditions
  '''
  def __init__(self, max_speed: int, current_speed=0):

    self.max_speed = max_speed
    self.current_speed = current_speed

    if self.current_speed > 0:
      self.state = 'On the road'
      Car.TOTAL_CARS = Car.TOTAL_CARS + 1
    else:
      self.state = 'On the parking'

  def accelerate(self, upper_border=None, step=10):

    current = self.current_speed

    if self.state == 'On the parking':
      self.state == 'On the road'
      Car.TOTAL_CARS = Car.TOTAL_CARS + 1
    speed = IncreaseSpeed(self.current_speed, upper_border, step)

    if speed.max_speed > speed.current_speed:
      for i in speed:
          print("INFO: Speed increases by", speed.step)
    else:
      next(speed)

    self.current_speed = speed.current_speed
    print(f"INFO: The speed of this car has increased from {current} to {speed.current_speed}")
    #When I tried using return it didn't produce the expected output as in the example file so I decided to stick to a print statement

    # check for state
    # create an instance of IncreaseSpeed iterator
    # check if smth passed to upper_border and if it is valid speed value
    # if True, increase the speed gradually iterating over your increaser until upper_border is met
    # print a message at each speed increase
    # else increase the speed once
    # return the message with current speed


  def brake(self, lower_border=None, step=10):

    current = self.current_speed
    speed = DecreaseSpeed(self.current_speed, lower_border, step)

    if speed.min_speed < speed.current_speed and speed.min_speed >= 0:
      for i in speed:
          print("INFO: Speed decreases by", speed.step)
    else:
      next(speed)

    self.current_speed = speed.current_speed
    print(f"INFO: The speed of this car has decreased from {current} to {speed.current_speed}")

    # create an instance of DecreaseSpeed iterator
    # check if smth passed to lower_border and if it is valid speed value
    # if True, decrease the speed gradually iterating over your decreaser until lower_border is met
    # print a message at each speed decrease
    # else increase the speed once
    # return the message with current speed

  # the next three functions you have to define yourself
  # one of the is class method, one - static and one - regular method (not necessarily in this order, it's for you to think)

  def parking(self):

    if self.state == "On the road":
      print(f'INFO: The speed of this car has decreased from {self.current_speed} to 0')
      self.current_speed = 0
      self.state == 'On parking'
      Car.TOTAL_CARS = Car.TOTAL_CARS - 1

    else:
      print("You're car is already on parking")
    # gets car off the road (use state and class variable)
    # check: should not be able to move the car off the road if it's not there

  @classmethod
  def total_cars(cls):
    # displays total amount of cars on the road
    return cls.TOTAL_CARS

  @staticmethod
  def show_weather():

    openmeteo = openmeteo_requests.Client()
    url = "https://api.open-meteo.com/v1/forecast"
    params = {
    "latitude": 59.9386, # for St.Petersburg
    "longitude": 30.3141, # for St.Petersburg
    "current": ["temperature_2m", "apparent_temperature", "rain", "wind_speed_10m"],
    "wind_speed_unit": "ms",
    "timezone": "Europe/Moscow"
    }

    response = openmeteo.weather_api(url, params=params)[0]

    # The order of variables needs to be the same as requested in params->current!
    current = response.Current()
    current_temperature_2m = current.Variables(0).Value()
    current_apparent_temperature = current.Variables(1).Value()
    current_rain = current.Variables(2).Value()
    current_wind_speed_10m = current.Variables(3).Value()

    print(f"Current time: {datetime.fromtimestamp(current.Time()+response.UtcOffsetSeconds())} {response.TimezoneAbbreviation().decode()}")
    print(f"Current temperature: {round(current_temperature_2m, 0)} C")
    print(f"Current apparent_temperature: {round(current_apparent_temperature, 0)} C")
    print(f"Current rain: {current_rain} mm")
    print(f"Current wind_speed: {round(current_wind_speed_10m, 1)} m/s")
    # displays weather conditions
# Out:
# Requirement already satisfied: openmeteo_requests in /usr/local/lib/python3.12/dist-packages (1.7.5)
# Requirement already satisfied: niquests>=3.15.2 in /usr/local/lib/python3.12/dist-packages (from openmeteo_requests) (3.18.2)
# Requirement already satisfied: openmeteo-sdk>=1.22.0 in /usr/local/lib/python3.12/dist-packages (from openmeteo_requests) (1.26.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from niquests>=3.15.2->openmeteo_requests) (3.4.6)
# Requirement already satisfied: urllib3-future<3,>=2.13.903 in /usr/local/lib/python3.12/dist-packages (from niquests>=3.15.2->openmeteo_requests) (2.18.900)
# Requirement already satisfied: wassima<3,>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from niquests>=3.15.2->openmeteo_requests) (2.0.5)
# Requirement already satisfied: flatbuffers==25.9.23 in /usr/local/lib/python3.12/dist-packages (from openmeteo-sdk>=1.22.0->openmeteo_requests) (25.9.23)
# Requirement already satisfied: h11<1.0.0,>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from urllib3-future<3,>=2.13.903->niquests>=3.15.2->openmeteo_requests) (0.16.0)
# Requirement already satisfied: jh2<6.0.0,>=5.0.3 in /usr/local/lib/python3.12/dist-packages (from urllib3-future<3,>=2.13.903->niquests>=3.15.2->openmeteo_requests) (5.0.10)
# Requirement already satisfied: qh3<2.0.0,>=1.5.4 in /usr/local/lib/python3.12/dist-packages (from urllib3-future<3,>=2.13.903->niquests>=3.15.2->openmeteo_requests) (1.7.0)

# %%
car1 = Car(100, 20) # max_speed = 100, initial speed = 5
car2 = Car(60, 30) # max_speed = 60, initial speed = 30
car3 = Car(100, 0) # a car that is off road upon creation
print(f"Total cars on road: {Car.total_cars()}")
# Out:
# Total cars on road: 2

# %%
car1.accelerate(100)
# Out:
# INFO: Speed increases by 10
# INFO: Speed increases by 10
# INFO: Speed increases by 10
# INFO: Speed increases by 10
# INFO: Speed increases by 10
# INFO: Speed increases by 10
# INFO: Speed increases by 10
# INFO: Speed increases by 10
# INFO: The speed of this car has increased from 20 to 100

# %%
car2.accelerate(50)
# Out:
# INFO: Speed increases by 10
# INFO: Speed increases by 10
# INFO: The speed of this car has increased from 30 to 50

# %%
print("Speed of car 1:", car1.current_speed)
# Out:
# Speed of car 1: 100

# %%
print("Speed of car 2:", car2.current_speed)
# Out:
# Speed of car 2: 50

# %%
car2.brake(0)
print("Total cars on road:", Car.total_cars())
car2.parking()
print("Total cars on road:", Car.total_cars())
# Out:
# INFO: Speed decreases by 10
# INFO: Speed decreases by 10
# INFO: Speed decreases by 10
# INFO: Speed decreases by 10
# INFO: Speed decreases by 10
# INFO: The speed of this car has decreased from 50 to 0
# Total cars on road: 2
# INFO: The speed of this car has decreased from 0 to 0
# Total cars on road: 1

# %%
car3.accelerate(80)# car3 is now on the road
car3.show_weather()
print("Total cars on road:", Car.total_cars())
# Out:
# INFO: Speed increases by 10
# INFO: Speed increases by 10
# INFO: Speed increases by 10
# INFO: Speed increases by 10
# INFO: Speed increases by 10
# INFO: Speed increases by 10
# INFO: Speed increases by 10
# INFO: Speed increases by 10
# INFO: The speed of this car has increased from 0 to 80
# Current time: 2026-03-25 20:30:00 GMT+3
# Current temperature: 10.0 C
# Current apparent_temperature: 6.0 C
# Current rain: 0.0 mm
# Current wind_speed: 5.2 m/s
# Total cars on road: 2

# %%
car2.accelerate(10) # # car2 goes from parking on the road
print("Total cars on road:", Car.total_cars())
# Out:
# INFO: Speed increases by 10
# INFO: The speed of this car has increased from 0 to 10
# Total cars on road: 2

# %%
Car.show_weather()
# Out:
# Current time: 2026-03-25 20:30:00 GMT+3
# Current temperature: 10.0 C
# Current apparent_temperature: 6.0 C
# Current rain: 0.0 mm
# Current wind_speed: 5.2 m/s
